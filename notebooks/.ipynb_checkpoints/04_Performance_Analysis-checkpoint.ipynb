# %% [markdown]
# # Day 4: Performance Analysis

# %% [markdown]
# This notebook builds a Mutual Fund Performance Scorecard by analysing historical NAV data and comparing against Nifty 50 and Nifty 100 benchmarks.
#
# **Deliverables:** `Performance_Analytics.ipynb`, `fund_scorecard.csv`, `alpha_beta.csv`, `benchmark_comparison.png`

# %% [markdown]
# # Section 1: Imports

# %%
import os
import warnings
warnings.filterwarnings("ignore")

import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

from scipy.stats import linregress

plt.style.use("ggplot")
pd.set_option("display.max_columns", None)
pd.set_option("display.float_format", "{:.6f}".format)

# %% [markdown]
# # Section 2: Load Data

# %%
nav       = pd.read_csv("../data/processed/clean_02_nav_history.csv",
                        parse_dates=["date"])        # FIX: parse_dates added
benchmark = pd.read_csv("../data/raw/10_benchmark_indices.csv")
funds     = pd.read_csv("../data/raw/01_fund_master.csv")

print("nav shape      :", nav.shape)
print("benchmark shape:", benchmark.shape)
print("funds shape    :", funds.shape)
print("nav dtypes:\n", nav.dtypes)
# Out:
# nav shape      : (46000, 3)
# benchmark shape: (8050, 3)
# funds shape    : (40, 15)
# nav dtypes:
#  amfi_code             int64
# date         datetime64[us]
# nav                 float64
# dtype: object

# %%
# Ensure output directories exist before any file write
os.makedirs("../reports/performance", exist_ok=True)
os.makedirs("../reports",             exist_ok=True)
print("Output directories ready.")
# Out:
# Output directories ready.

# %% [markdown]
# # Section 3: Data Preparation

# %%
benchmark["date"] = pd.to_datetime(benchmark["date"])   # nav date already parsed above

nav       = nav.sort_values(["amfi_code", "date"]).reset_index(drop=True)
benchmark = benchmark.sort_values("date").reset_index(drop=True)

print("Date range (nav)      :", nav["date"].min().date(), "->", nav["date"].max().date())
print("Date range (benchmark):", benchmark["date"].min().date(), "->", benchmark["date"].max().date())
print("Unique funds:", nav["amfi_code"].nunique())
# Out:
# Date range (nav)      : 2022-01-03 -> 2026-05-29
# Date range (benchmark): 2022-01-03 -> 2026-05-29
# Unique funds: 40

# %% [markdown]
# # Section 4: Daily Returns
#
# **Formula:**
# $$\text{Return}_t = \frac{\text{NAV}_t}{\text{NAV}_{t-1}} - 1$$

# %%
nav["daily_return"] = (
    nav.groupby("amfi_code")["nav"]
       .pct_change()
)

print(f"Daily returns computed. Non-null rows: {nav['daily_return'].notna().sum():,}")
nav.head()
# Out:
# Daily returns computed. Non-null rows: 45,960
#    amfi_code       date        nav  daily_return
# 0     100016 2022-01-03 520.460800           NaN
# 1     100016 2022-01-04 515.097100     -0.010306
# 2     100016 2022-01-05 521.723900      0.012865
# 3     100016 2022-01-06 515.788000     -0.011377
# 4     100016 2022-01-07 515.163900     -0.001210

# %% [markdown]
# ### Check distribution:

# %%
plt.figure(figsize=(10, 5))
sns.histplot(nav["daily_return"].dropna(), bins=100)
plt.title("Daily Return Distribution -- All 40 Funds")
plt.xlabel("Daily Return")
plt.ylabel("Frequency")
plt.tight_layout()
plt.savefig("../reports/performance/daily_return_distribution.png", dpi=150)
plt.show()
print("Distribution looks reasonable: bell-shaped, centred near 0.")
# Out:
# Distribution looks reasonable: bell-shaped, centred near 0.

# %% [markdown]
# # Section 5: CAGR
#
# **Function:**

# %%
def calculate_cagr(df, years):
    latest = df["date"].max()
    start  = latest - pd.DateOffset(years=years)
    temp   = df[df["date"] >= start].sort_values("date")

    if len(temp) < 2:
        return None

    start_nav = temp.iloc[0]["nav"]
    end_nav   = temp.iloc[-1]["nav"]

    return (end_nav / start_nav) ** (1 / years) - 1

# %% [markdown]
# **Calculate 1yr, 3yr, 5yr CAGR for all funds:**

# %%
cagr_results = []

for code, grp in nav.groupby("amfi_code"):
    try:
        cagr_1 = calculate_cagr(grp, 1)
        cagr_3 = calculate_cagr(grp, 3)
        cagr_5 = calculate_cagr(grp, 5)   # FIX: 5yr CAGR was entirely missing
        cagr_results.append([code, cagr_1, cagr_3, cagr_5])
    except Exception as e:
        print(f"Skipping {code}: {e}")

cagr_df = pd.DataFrame(
    cagr_results,
    columns=["amfi_code", "cagr_1y", "cagr_3y", "cagr_5y"]   # FIX: cagr_5y column added
)

print(f"CAGR computed for {len(cagr_df)} funds")
print("\nCAGR comparison table (all funds):")
print(
    cagr_df.merge(funds[["amfi_code", "scheme_name"]], on="amfi_code", how="left")
           [["scheme_name", "cagr_1y", "cagr_3y", "cagr_5y"]]
           .sort_values("cagr_3y", ascending=False)
           .to_string(index=False)
)
# Out:
# CAGR computed for 40 funds
#
# CAGR comparison table (all funds):
#                                           scheme_name   cagr_1y   cagr_3y  cagr_5y
#                   Axis Midcap Fund - Regular - Growth  0.222611  0.351118 0.244453
#         Mirae Asset Large Cap Fund - Regular - Growth  0.203607  0.340009 0.267993
#             ICICI Pru Bluechip Fund - Direct - Growth  0.130643  0.324874 0.202340
#    HDFC Mid-Cap Opportunities Fund - Regular - Growth  0.532324  0.324425 0.260741
#              ICICI Pru Midcap Fund - Regular - Growth  0.296047  0.317775 0.283768
#             SBI Bluechip Fund - Regular Plan - Growth  0.604373  0.304565 0.223849
#                Kotak Flexicap Fund - Regular - Growth  0.266571  0.295828 0.267425
#         Mirae Asset Tax Saver Fund - Regular - Growth  0.397518  0.291789 0.276299
#         ABSL Frontline Equity Fund - Regular - Growth  0.479241  0.289677 0.204427
# ...

# %% [markdown]
# # Section 6: Sharpe Ratio

# %%
RF = 0.065   # 6.5% annualised risk-free rate (RBI repo rate proxy)

sharpe_list = []

for code, grp in nav.groupby("amfi_code"):
    r = grp["daily_return"].dropna()

    annual_return = r.mean() * 252
    annual_vol    = r.std()  * np.sqrt(252)

    sharpe = (annual_return - RF) / annual_vol
    sharpe_list.append([code, sharpe])

sharpe_df = pd.DataFrame(
    sharpe_list,
    columns=["amfi_code", "sharpe_ratio"]
)

# FIX: use a display copy so sharpe_df index stays clean for the merge later
sharpe_display = (
    sharpe_df
    .sort_values("sharpe_ratio", ascending=False)
    .reset_index(drop=True)
)
sharpe_display.index += 1
sharpe_display.index.name = "rank"

print("Top 40 funds by Sharpe Ratio:")
sharpe_display.head(40)
# Out:
# Top 40 funds by Sharpe Ratio:
#       amfi_code  sharpe_ratio
# rank
# 1        148567      1.448291
# 2        120843      1.306744
# 3        148569      1.234930
# 4        119551      1.208267
# 5        120505      1.180101
# 6        149323      1.132122
# 7        100033      1.093699
# 8        118632      1.081659
# 9        101206      1.027213
# 10       120504      1.026524
# 11       119094      0.998231
# 12       119552      0.953279
# 13       149324      0.949796
# 14       119598      0.945308
# 15       148568      0.926287
# 16       102885      0.817099
# 17       120503      0.797973
# 18       125497      0.775790
# 19       118635      0.664857
# 20       120506      0.648879
# 21       118633      0.645207
# 22       102887      0.619518
# 23       120507      0.495723
# 24       120841      0.494273
# 25       149322      0.464037
# 26       118634      0.448434
# 27       125498      0.300612
# 28       101207      0.162661
# 29       119093      0.129614
# ...

# %% [markdown]
# # Section 7: Sortino Ratio

# %%
sortino_list = []

for code, grp in nav.groupby("amfi_code"):
    r = grp["daily_return"].dropna()

    downside      = r[r < 0]
    annual_return = r.mean() * 252
    downside_std  = downside.std() * np.sqrt(252)

    sortino = (annual_return - RF) / downside_std
    sortino_list.append([code, sortino])

sortino_df = pd.DataFrame(
    sortino_list,
    columns=["amfi_code", "sortino_ratio"]
)

print(f"Sortino computed for {len(sortino_df)} funds")
sortino_df.head()
# Out:
# Sortino computed for 40 funds
#    amfi_code  sortino_ratio
# 0     100016      -0.351047
# 1     100025      -0.941821
# 2     100033       1.829134
# 3     101206       1.799563
# 4     101207       0.276644

# %% [markdown]
# # Section 8: Alpha & Beta
#
# Use NIFTY100 as the regression benchmark.

# %%
nifty100 = benchmark[
    benchmark["index_name"] == "NIFTY100"
].copy()

nifty100 = nifty100.sort_values("date")
nifty100["benchmark_return"] = nifty100["close_value"].pct_change()

print(f"Nifty100 rows: {len(nifty100):,}")
# Out:
# Nifty100 rows: 1,150

# %% [markdown]
# ### Calculate Alpha & Beta

# %%
alpha_beta = []

for code, grp in nav.groupby("amfi_code"):
    merged = pd.merge(
        grp,
        nifty100[["date", "benchmark_return"]],
        on="date"
    ).dropna()

    if len(merged) < 50:
        continue

    # linregress(x, y): slope=beta, intercept=alpha
    beta, alpha, r_val, p_val, stderr = linregress(
        merged["benchmark_return"],
        merged["daily_return"]
    )

    alpha_beta.append([code, alpha * 252, beta])   # alpha annualised

alpha_beta_df = pd.DataFrame(
    alpha_beta,
    columns=["amfi_code", "alpha", "beta"]
)

print(f"Alpha/Beta computed for {len(alpha_beta_df)} funds")
alpha_beta_df.head(10)
# Out:
# Alpha/Beta computed for 40 funds
#    amfi_code    alpha      beta
# 0     100016 0.037476 -0.058268
# 1     100025 0.042818  0.001158
# 2     100033 0.271954  0.005104
# 3     101206 0.213998  0.021086
# 4     101207 0.108971 -0.065289
# 5     101208 0.060861  0.000267
# 6     102885 0.170488 -0.019487
# 7     102886 0.028969 -0.042125
# 8     102887 0.162113  0.016683
# 9     118632 0.218294 -0.008354

# %% [markdown]
# # Section 9: Maximum Drawdown

# %%
drawdown_list = []

for code, grp in nav.groupby("amfi_code"):
    grp = grp.sort_values("date").copy()

    grp["running_max"] = grp["nav"].cummax()
    grp["drawdown"]    = (grp["nav"] / grp["running_max"]) - 1

    max_dd     = grp["drawdown"].min()
    trough_idx = grp["drawdown"].idxmin()
    peak_idx   = grp.loc[:trough_idx, "nav"].idxmax()

    drawdown_list.append([
        code,
        max_dd,
        grp.loc[peak_idx,   "date"],
        grp.loc[trough_idx, "date"]
    ])

drawdown_df = pd.DataFrame(
    drawdown_list,
    columns=["amfi_code", "max_drawdown", "dd_start", "dd_end"]
)

print(f"Drawdown computed for {len(drawdown_df)} funds")
print(f"Worst drawdown overall: {drawdown_df['max_drawdown'].min():.2%}")
drawdown_df.head()
# Out:
# Drawdown computed for 40 funds
# Worst drawdown overall: -52.57%
#    amfi_code  max_drawdown   dd_start     dd_end
# 0     100016     -0.247344 2022-03-30 2022-09-15
# 1     100025     -0.043083 2023-05-23 2023-07-28
# 2     100033     -0.162172 2022-03-11 2022-05-12
# 3     101206     -0.112916 2023-04-24 2023-07-05
# 4     101207     -0.354469 2024-11-21 2026-05-11

# %% [markdown]
# # Section 10: Tracking Error
#
# Tracking error = $\text{std}(r_{\text{fund}} - r_{\text{benchmark}}) \times \sqrt{252}$
#
# Computed vs **Nifty 100** (regression benchmark) and **Nifty 50** (primary index).

# %%
# Nifty50 returns
nifty50 = benchmark[benchmark["index_name"] == "NIFTY50"].copy()
nifty50 = nifty50.sort_values("date")
nifty50["benchmark_return_50"] = nifty50["close_value"].pct_change()

tracking = []

for code, grp in nav.groupby("amfi_code"):

    # Tracking error vs Nifty100
    m100 = pd.merge(grp, nifty100[["date", "benchmark_return"]], on="date").dropna()
    te100 = (m100["daily_return"] - m100["benchmark_return"]).std() * np.sqrt(252)

    # FIX: Tracking error vs Nifty50 (spec lists both benchmarks)
    m50 = pd.merge(grp, nifty50[["date", "benchmark_return_50"]], on="date").dropna()
    te50  = (m50["daily_return"] - m50["benchmark_return_50"]).std() * np.sqrt(252)

    tracking.append([code, te100, te50])

tracking_df = pd.DataFrame(
    tracking,
    columns=["amfi_code", "tracking_error_nifty100", "tracking_error_nifty50"]
)

print(f"Tracking error computed for {len(tracking_df)} funds")
tracking_df.head()
# Out:
# Tracking error computed for 40 funds
#    amfi_code  tracking_error_nifty100  tracking_error_nifty50
# 0     100016                 0.199284                0.196416
# 1     100025                 0.134535                0.136445
# 2     100033                 0.228699                0.229755
# 3     101206                 0.192706                0.191469
# 4     101207                 0.292117                0.291700

# %% [markdown]
# # Section 11: Fund Scorecard
#
# ### Merge all metrics.

# %%
scorecard = (
    cagr_df
    .merge(sharpe_df,     on="amfi_code")
    .merge(sortino_df,    on="amfi_code")    # FIX: was never merged
    .merge(alpha_beta_df, on="amfi_code")
    .merge(drawdown_df,   on="amfi_code")
    .merge(tracking_df,   on="amfi_code")    # FIX: was never merged
    .merge(
        funds[["amfi_code", "expense_ratio_pct", "scheme_name"]],
        on="amfi_code"
    )
)

print(f"Scorecard shape: {scorecard.shape}")
print("Columns:", scorecard.columns.tolist())
# Out:
# Scorecard shape: (40, 15)
# Columns: ['amfi_code', 'cagr_1y', 'cagr_3y', 'cagr_5y', 'sharpe_ratio', 'sortino_ratio', 'alpha', 'beta', 'max_drawdown', 'dd_start', 'dd_end', 'tracking_error_nifty100', 'tracking_error_nifty50', 'expense_ratio_pct', 'scheme_name']

# %% [markdown]
# ### Ranking

# %%
n = len(scorecard)

# Higher is better -> rank descending (rank 1 = best)
scorecard["cagr_rank"]    = scorecard["cagr_3y"].rank(ascending=False)
scorecard["sharpe_rank"]  = scorecard["sharpe_ratio"].rank(ascending=False)
scorecard["alpha_rank"]   = scorecard["alpha"].rank(ascending=False)

# Lower is better -> rank ascending (rank 1 = lowest/best)
scorecard["expense_rank"] = scorecard["expense_ratio_pct"].rank(ascending=True)

# FIX: removed dead first line (ascending=True, wrong direction).
# max_drawdown is negative; ascending=False -> rank 1 = least negative = best.
scorecard["dd_rank"]      = scorecard["max_drawdown"].rank(ascending=False)

# Normalise each rank to 0-100  (rank 1 -> 100, rank n -> ~0)
for col in ["cagr_rank", "sharpe_rank", "alpha_rank", "expense_rank", "dd_rank"]:
    scorecard[col] = (n - scorecard[col]) / (n - 1) * 100

print("Ranks normalised to 0-100.")
scorecard[["amfi_code", "cagr_rank", "sharpe_rank", "alpha_rank",
           "expense_rank", "dd_rank"]].head()
# Out:
# Ranks normalised to 0-100.
#    amfi_code  cagr_rank  sharpe_rank  alpha_rank  expense_rank   dd_rank
# 0     100016  12.820513    12.820513    2.564103     20.512821 15.384615
# 1     100025  15.384615     2.564103    5.128205     97.435897 92.307692
# 2     100033  92.307692    84.615385   87.179487     58.974359 51.282051
# 3     101206  79.487179    79.487179   71.794872      8.974359 79.487179
# 4     101207   2.564103    30.769231   33.333333     29.487179  5.128205

# %% [markdown]
# ### Composite Score (0-100)

# %%
scorecard["fund_score"] = (
      scorecard["cagr_rank"]    * 0.30   # 30% -- 3yr CAGR rank
    + scorecard["sharpe_rank"]  * 0.25   # 25% -- Sharpe rank
    + scorecard["alpha_rank"]   * 0.20   # 20% -- Alpha rank
    + scorecard["expense_rank"] * 0.15   # 15% -- Expense ratio rank (inverse)
    + scorecard["dd_rank"]      * 0.10   # 10% -- Max drawdown rank (inverse)
)

scorecard = (
    scorecard
    .sort_values("fund_score", ascending=False)
    .reset_index(drop=True)
)
scorecard.index += 1
scorecard.index.name = "rank"

print("Top 10 Funds by Composite Score:")
scorecard[[
    "scheme_name", "cagr_3y", "sharpe_ratio", "sortino_ratio",
    "alpha", "beta", "max_drawdown", "expense_ratio_pct", "fund_score"
]].head(10)
# Out:
# Top 10 Funds by Composite Score:
#                                             scheme_name  cagr_3y  \
# rank
# 1         Mirae Asset Large Cap Fund - Regular - Growth 0.340009
# 2              ICICI Pru Midcap Fund - Regular - Growth 0.317775
# 3                Kotak Flexicap Fund - Regular - Growth 0.295828
# 4     HDFC Mid-Cap Opportunities Fund - Regular - Gr... 0.324425
# 5             ICICI Pru Bluechip Fund - Direct - Growth 0.324874
# 6                   Axis Midcap Fund - Regular - Growth 0.351118
# 7             SBI Bluechip Fund - Regular Plan - Growth 0.304565
# 8         Mirae Asset Tax Saver Fund - Regular - Growth 0.291789
# 9         ABSL Frontline Equity Fund - Regular - Growth 0.289677
# 10           SBI Small Cap Fund - Regular Plan - Growth 0.266699
#
#       sharpe_ratio  sortino_ratio    alpha      beta  max_drawdown  \
# rank
# 1         1.448291       2.385644 0.269838  0.023684     -0.112657
# ...

# %% [markdown]
# # Section 12: Benchmark Comparison
#
# Top 5 funds (by composite score) vs Nifty 50 and Nifty 100 — last 3 years, base-100 normalised.
#
# **Note:** Stale Cell 35 from the original notebook (raw NAV, no filter, no benchmarks) has been removed.

# %%
# Top 5 Funds by Composite Score
top5 = (
    scorecard
    .sort_values("fund_score", ascending=False)
    .head(5)["amfi_code"]
    .tolist()
)
print("Top 5 Funds:", top5)

# Filter Last 3 Years
latest_date = nav["date"].max()
start_date  = latest_date - pd.DateOffset(years=3)

nav_3y = nav[
    (nav["date"] >= start_date) & nav["amfi_code"].isin(top5)
].copy()

benchmark_3y = benchmark[
    (benchmark["date"] >= start_date) &
    benchmark["index_name"].isin(["NIFTY50", "NIFTY100"])
].copy()

# Normalise Funds (Base = 100)
fund_frames = []
for code in top5:
    temp = nav_3y[nav_3y["amfi_code"] == code].sort_values("date").copy()
    if len(temp) == 0:
        continue
    base_nav = temp["nav"].iloc[0]
    temp["normalized_value"] = (temp["nav"] / base_nav) * 100
    name_series = funds.loc[funds["amfi_code"] == code, "scheme_name"]
    temp["series"] = name_series.iloc[0] if len(name_series) > 0 else str(code)
    fund_frames.append(temp[["date", "series", "normalized_value"]])

fund_plot = pd.concat(fund_frames, ignore_index=True)

# Normalise Benchmarks (Base = 100)
benchmark_frames = []
for idx in ["NIFTY50", "NIFTY100"]:
    temp = benchmark_3y[benchmark_3y["index_name"] == idx].sort_values("date").copy()
    if len(temp) == 0:
        continue
    base_price = temp["close_value"].iloc[0]
    temp["normalized_value"] = (temp["close_value"] / base_price) * 100
    temp["series"] = idx
    benchmark_frames.append(temp[["date", "series", "normalized_value"]])

benchmark_plot = pd.concat(benchmark_frames, ignore_index=True)

# Combine & Plot
plot_df = pd.concat([fund_plot, benchmark_plot], ignore_index=True)

fig = px.line(
    plot_df,
    x="date", y="normalized_value", color="series",
    title="Top 5 Funds vs NIFTY50 vs NIFTY100 (Last 3 Years, Base = 100)"
)
fig.update_layout(
    xaxis_title="Date",
    yaxis_title="Normalised Growth (Base = 100)",
    legend_title="Fund / Benchmark",
    height=700
)
fig.show()

fig.write_image("../reports/benchmark_comparison.png", width=1400, height=700, scale=2)
print("benchmark_comparison.png saved.")

# Tracking Error Summary for Top 5
print("\nTracking Error for Top 5 Funds:")
top5_te = (
    tracking_df[tracking_df["amfi_code"].isin(top5)]
    .merge(funds[["amfi_code", "scheme_name"]], on="amfi_code", how="left")
    [["scheme_name", "tracking_error_nifty100", "tracking_error_nifty50"]]
    .reset_index(drop=True)
)
print(top5_te.to_string(index=False))
# Out:
# Top 5 Funds: [148567, 120505, 120843, 100033, 120504]
# benchmark_comparison.png saved.
#
# Tracking Error for Top 5 Funds:
#                                        scheme_name  tracking_error_nifty100  tracking_error_nifty50
# HDFC Mid-Cap Opportunities Fund - Regular - Growth                 0.228699                0.229755
#          ICICI Pru Bluechip Fund - Direct - Growth                 0.191587                0.191376
#           ICICI Pru Midcap Fund - Regular - Growth                 0.231968                0.233124
#             Kotak Flexicap Fund - Regular - Growth                 0.206425                0.205148
#      Mirae Asset Large Cap Fund - Regular - Growth                 0.189664                0.193996

# %% [markdown]
# # Section 13: Export Deliverables

# %%
# CAGR report (now includes 5yr)
cagr_df.to_csv("../reports/performance/cagr_report.csv", index=False)

# Alpha / Beta
alpha_beta_df.to_csv("../reports/performance/alpha_beta.csv", index=False)

# Sortino report  [FIX: was never exported]
sortino_df.to_csv("../reports/performance/sortino_report.csv", index=False)

# Tracking error  [FIX: was never exported]
tracking_df.to_csv("../reports/performance/tracking_error.csv", index=False)

# Fund scorecard (full, includes sortino + tracking columns)
scorecard.reset_index().to_csv("../reports/performance/fund_scorecard.csv", index=False)

print("All deliverables saved:")
print("  [OK] ../reports/performance/cagr_report.csv      -- 1yr, 3yr, 5yr CAGR")
print("  [OK] ../reports/performance/alpha_beta.csv       -- Alpha & Beta")
print("  [OK] ../reports/performance/sortino_report.csv   -- Sortino ratios")
print("  [OK] ../reports/performance/tracking_error.csv   -- Tracking error vs Nifty50 & 100")
print("  [OK] ../reports/performance/fund_scorecard.csv   -- Full composite scorecard")
print("  [OK] ../reports/benchmark_comparison.png         -- Benchmark chart")
# Out:
# All deliverables saved:
#   [OK] ../reports/performance/cagr_report.csv      -- 1yr, 3yr, 5yr CAGR
#   [OK] ../reports/performance/alpha_beta.csv       -- Alpha & Beta
#   [OK] ../reports/performance/sortino_report.csv   -- Sortino ratios
#   [OK] ../reports/performance/tracking_error.csv   -- Tracking error vs Nifty50 & 100
#   [OK] ../reports/performance/fund_scorecard.csv   -- Full composite scorecard
#   [OK] ../reports/benchmark_comparison.png         -- Benchmark chart
