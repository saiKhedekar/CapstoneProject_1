# %% [markdown]
# # Capstone Project Day 1 -  Understanding Data

# %%
# Cell 1 — Project Setup
import pandas as pd
import requests
import json
from pathlib import Path

pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", 100)

# %%
# Cell 2 — Paths
# Since notebooks run differently from scripts, avoid __file__.

from pathlib import Path

BASE_DIR = Path.cwd().parent

RAW_DIR   = BASE_DIR / "data" / "raw"
LIVE_DIR  = BASE_DIR / "data" / "live_nav"
REPORT_DIR = BASE_DIR / "reports"

LIVE_DIR.mkdir(exist_ok=True)
REPORT_DIR.mkdir(exist_ok=True)

print(BASE_DIR)
# Out:
# C:\Users\Sai Khedekar\Desktop\CapstoneProject_1

# %%
# Cell 3 — Dataset Registry
datasets = {
    "fund_master":   "01_fund_master.csv",
    "nav_history":   "02_nav_history.csv",
    "aum":           "03_aum_by_fund_house.csv",
    "sip":           "04_monthly_sip_inflows.csv",
    "category":      "05_category_inflows.csv",
    "folio":         "06_industry_folio_count.csv",
    "performance":   "07_scheme_performance.csv",
    "transactions":  "08_investor_transactions.csv",
    "portfolio":     "09_portfolio_holdings.csv",
    "benchmark":     "10_benchmark_indices.csv"
}

# %%
# Cell 4 — Load All Datasets
loaded_data = {}

for name, file in datasets.items():

    df = pd.read_csv(RAW_DIR / file)

    loaded_data[name] = df

    print("\n" + "="*60)
    print(name.upper())
    print("="*60)

    print("Shape :", df.shape)
    print("")
    display(df.head())
# Out:
# ...
# FUND_MASTER
# ...
# Shape : (40, 15)
#
# Datatypes:
# amfi_code               int64
# fund_house                str
# scheme_name               str
# category                  str
# sub_category              str
# plan                      str
# launch_date               str
# benchmark                 str
# expense_ratio_pct     float64
# exit_load_pct         float64
# min_sip_amount          int64
# min_lumpsum_amount      int64
# fund_manager              str
# risk_category             str
# sebi_category_code        str
# dtype: object
#    amfi_code       fund_house                                   scheme_name  \
# 0     119551  SBI Mutual Fund     SBI Bluechip Fund - Regular Plan - Growth
# 1     119552  SBI Mutual Fund      SBI Bluechip Fund - Direct Plan - Growth
# 2     119598  SBI Mutual Fund    SBI Small Cap Fund - Regular Plan - Growth
# 3     119599  SBI Mutual Fund     SBI Small Cap Fund - Direct Plan - Growth
# ...

# %%
# Cell 5 — Dataset Summary Report
summary = []

for name, df in loaded_data.items():

    summary.append({
        "Dataset":        name,
        "Rows":           df.shape[0],
        "Columns":        df.shape[1],
        "Missing Values": df.isnull().sum().sum(),
        "Duplicates":     df.duplicated().sum()
    })

summary_df = pd.DataFrame(summary)

summary_df
# Out:
#         Dataset   Rows  Columns  Missing Values  Duplicates
# 0   fund_master     40       15               0           0
# 1   nav_history  46000        3               0           0
# 2           aum     90        5               0           0
# 3           sip     48        6              12           0
# 4      category    144        3               0           0
# 5         folio     21        6               0           0
# 6   performance     40       19               0           0
# 7  transactions  32778       13               0           0
# 8     portfolio    322        8               0           0
# 9     benchmark   8050        3               0           0

# %%
# Cell 6 — Save Summary
summary_df.to_csv(
    REPORT_DIR / "dataset_summary.csv",
    index=False
)

print("Dataset summary saved")
# Out:
# Dataset summary saved

# %%
# Cell 7 — Dataset Information
for name, df in loaded_data.items():

    print("\n" + "="*60)
    print(name.upper())
    print("="*60)

    print("\nData Types")
    print(df.dtypes)

    print("\nMissing Values")
    print(df.isnull().sum())

    print("\nDuplicates")
    print(df.duplicated().sum())
# Out:
# ...
# FUND_MASTER
# ...
#
# Data Types
# amfi_code               int64
# fund_house                str
# scheme_name               str
# category                  str
# sub_category              str
# plan                      str
# launch_date               str
# benchmark                 str
# expense_ratio_pct     float64
# exit_load_pct         float64
# min_sip_amount          int64
# min_lumpsum_amount      int64
# fund_manager              str
# risk_category             str
# sebi_category_code        str
# dtype: object
#
# Missing Values
# amfi_code             0
# fund_house            0
# scheme_name           0
# category              0
# sub_category          0
# plan                  0
# launch_date           0
# benchmark             0
# expense_ratio_pct     0
# exit_load_pct         0
# min_sip_amount        0
# min_lumpsum_amount    0
# fund_manager          0
# risk_category         0
# sebi_category_code    0
# dtype: int64
#
# Duplicates
# 0
#
# ...
# NAV_HISTORY
# ...
#
# Data Types
# ...

# %% [markdown]
# # Analysing and Exploring fund_master.csv

# %%
# Cell 8 — Fund Master Analysis
fund_master = loaded_data["fund_master"]

fund_master.head()
# Out:
#    amfi_code       fund_house                                   scheme_name  \
# 0     119551  SBI Mutual Fund     SBI Bluechip Fund - Regular Plan - Growth
# 1     119552  SBI Mutual Fund      SBI Bluechip Fund - Direct Plan - Growth
# 2     119598  SBI Mutual Fund    SBI Small Cap Fund - Regular Plan - Growth
# 3     119599  SBI Mutual Fund     SBI Small Cap Fund - Direct Plan - Growth
# 4     119120  SBI Mutual Fund  SBI Magnum Gilt Fund - Regular Plan - Growth
#
#   category sub_category     plan launch_date                  benchmark  \
# 0   Equity    Large Cap  Regular  2006-02-14              NIFTY 100 TRI
# 1   Equity    Large Cap   Direct  2013-01-01              NIFTY 100 TRI
# 2   Equity    Small Cap  Regular  2009-09-09       BSE 250 SmallCap TRI
# 3   Equity    Small Cap   Direct  2013-01-01       BSE 250 SmallCap TRI
# 4     Debt         Gilt  Regular  2000-12-30  CRISIL Dynamic Gilt Index
#
#    expense_ratio_pct  exit_load_pct  min_sip_amount  min_lumpsum_amount  \
# ...

# %%
# Cell 9 — Unique Fund Houses
sorted(
    fund_master["fund_house"].unique()
)
# Out:
# ['Aditya Birla Sun Life MF',
#  'Axis Mutual Fund',
#  'DSP Mutual Fund',
#  'HDFC Mutual Fund',
#  'ICICI Prudential MF',
#  'Kotak Mahindra MF',
#  'Mirae Asset MF',
#  'Nippon India MF',
#  'SBI Mutual Fund',
#  'UTI Mutual Fund']

# %%
# Cell 10 — Categories
sorted(
    fund_master["category"].unique()
)
# Out:
# ['Debt', 'Equity']

# %%
# Cell 11 — Sub Categories
if "sub_category" in fund_master.columns:
    sorted(
        fund_master["sub_category"].unique()
    )

# %%
# Cell 12 — Risk Grades
if "risk_grade" in fund_master.columns:

    fund_master["risk_grade"] \
        .value_counts()

# %%
# Cell 13 — Fund House Distribution
fund_master["fund_house"] \
    .value_counts()
# Out:
# fund_house
# SBI Mutual Fund             5
# HDFC Mutual Fund            5
# ICICI Prudential MF         5
# Nippon India MF             5
# Kotak Mahindra MF           4
# Axis Mutual Fund            4
# Aditya Birla Sun Life MF    3
# UTI Mutual Fund             3
# Mirae Asset MF              3
# DSP Mutual Fund             3
# Name: count, dtype: int64

# %%
# Cell 14 — AMFI Code Validation
fund_codes = set(
    loaded_data["fund_master"]["amfi_code"]
)

nav_codes = set(
    loaded_data["nav_history"]["amfi_code"]
)

missing_codes = fund_codes - nav_codes

print("Fund Master Codes :", len(fund_codes))
print("NAV Codes         :", len(nav_codes))
print("Missing Codes     :", len(missing_codes))
# Out:
# Fund Master Codes : 40
# NAV Codes         : 40
# Missing Codes     : 0

# %%
# Cell 15 — Missing AMFI Codes
missing_codes
# Out:
# set()

# %%
# Cell 16 — Data Quality Report
quality_report = []

for name, df in loaded_data.items():

    quality_report.append({
        "Dataset":    name,
        "Rows":       df.shape[0],
        "Columns":    df.shape[1],
        "Missing":    df.isnull().sum().sum(),
        "Duplicates": df.duplicated().sum()
    })

quality_df = pd.DataFrame(
    quality_report
)

quality_df
# Out:
#         Dataset   Rows  Columns  Missing  Duplicates
# 0   fund_master     40       15        0           0
# 1   nav_history  46000        3        0           0
# 2           aum     90        5        0           0
# 3           sip     48        6       12           0
# 4      category    144        3        0           0
# 5         folio     21        6        0           0
# 6   performance     40       19        0           0
# 7  transactions  32778       13        0           0
# 8     portfolio    322        8        0           0
# 9     benchmark   8050        3        0           0

# %%
# Cell 17 — Save Data Quality Report
quality_df.to_csv(
    REPORT_DIR / "data_quality_report.csv",
    index=False
)

print("Data Quality Report Saved")
# Out:
# Data Quality Report Saved
